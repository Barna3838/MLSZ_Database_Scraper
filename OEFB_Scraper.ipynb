# %% [markdown]
# # OEFB Adatbank szkennelése
#
# ### Szükséges könyvtárak importálása

# %%
import pandas as pd
import requests
from requests import get
import numpy as np
from bs4 import BeautifulSoup
from urllib.request import urlopen
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
from random import randint

# %% [markdown]
# ### Adott játékos adatainak beszkennelése és tárolása
#
# Játékos adatlapja: https://www.oefb.at/bewerbe/Spieler/6732280?David-Graef
#
# A név nem szükséges a link címének megadásakor így könnyebben szkennelhető az adatbank viszont az üres adatlapok kezelését a későbbiekben felül kell vizsgálni.
#
# Tehát a link működik így is: https://www.oefb.at/bewerbe/Spieler/6732280

# %%
link = "https://www.oefb.at/bewerbe/Spieler/6732280"

page = requests.get(link)
bs = BeautifulSoup(page.text, 'lxml')
bs
# Out:
# <!DOCTYPE html>
# <html lang="de">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>David Gräf | oefb.at</title>
# <meta content="Position: Unbekannt, Rückennummer: 05, Mannschaft: AKA St. Pölten NÖ U 18 U18, Nationalität: Österreich" name="description"/>
# <meta content="oefb.at" name="Author"/>
# <!-- Schema.org markup for Google+ -->
# <meta content="David Gräf | oefb.at" itemprop="name"/>
# <meta content="Position: Unbekannt, Rückennummer: 05, Mannschaft: AKA St. Pölten NÖ U 18 U18, Nationalität: Österreich" itemprop="description"/>
# <meta content="https://www.oefb.at/bewerbe/oefb2/person/images/1278650591628556536_1b776e47f4e141a5d494-1,0-600x315-600x315.png" itemprop="image"/>
# <!-- Open Graph data -->
# <meta content="David Gräf | oefb.at" property="og:title"/>
# <meta content="Position: Unbekannt, Rückennummer: 05, Mannschaft: AKA St. Pölten NÖ U 18 U18, Nationalität: Österreich" property="og:description"/>
# ...

# %%
basedata = bs.findAll('head')
basedata[0]
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>David Gräf | oefb.at</title>
# <meta content="Position: Unbekannt, Rückennummer: 05, Mannschaft: AKA St. Pölten NÖ U 18 U18, Nationalität: Österreich" name="description"/>
# <meta content="oefb.at" name="Author"/>
# <!-- Schema.org markup for Google+ -->
# <meta content="David Gräf | oefb.at" itemprop="name"/>
# <meta content="Position: Unbekannt, Rückennummer: 05, Mannschaft: AKA St. Pölten NÖ U 18 U18, Nationalität: Österreich" itemprop="description"/>
# <meta content="https://www.oefb.at/bewerbe/oefb2/person/images/1278650591628556536_1b776e47f4e141a5d494-1,0-600x315-600x315.png" itemprop="image"/>
# <!-- Open Graph data -->
# <meta content="David Gräf | oefb.at" property="og:title"/>
# <meta content="Position: Unbekannt, Rückennummer: 05, Mannschaft: AKA St. Pölten NÖ U 18 U18, Nationalität: Österreich" property="og:description"/>
# ...

# %%
Player = bs.find("meta",  property="og:description")
Player["content"]
# Out:
# 'Position: Unbekannt, Rückennummer: 05, Mannschaft: AKA St. Pölten NÖ U 18 U18, Nationalität: Österreich'

# %%
Name = bs.find("title")
Name.get_text()
# Out:
# 'David Gräf | oefb.at'
